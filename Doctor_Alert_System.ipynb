# %% [markdown]
# # **Install**

# %%
# !pip install datasets
# !pip install jiwer
# !pip install gTTS
# !pip install --upgrade openai-whisper
# !pip install transformers accelerate torch sentencepiece fuzzywuzzy
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting jiwer
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from jiwer) (8.3.0)
# Collecting rapidfuzz>=3.9.7 (from jiwer)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 85.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-4.0.0 rapidfuzz-3.14.3
# Collecting gTTS
#   Downloading gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from gTTS) (2.32.4)
# Collecting click<8.2,>=7.1 (from gTTS)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2025.10.5)
# Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: click, gTTS
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
# Successfully installed click-8.1.8 gTTS-2.5.4
# Collecting openai-whisper
#   Downloading openai_whisper-20250625.tar.gz (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 34.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.0.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.8.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (4.67.1)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.12/dist-packages (from triton>=2->openai-whisper) (75.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (1.11.1.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->openai-whisper) (3.0.3)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=8336f90ee211eb48fb99a4b468a95f4e6ac83d3be10c7b93ebb0ee6234c8d8a8
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
# Successfully installed openai-whisper-20250625
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.11.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %% [markdown]
# # **Drive Mount**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **MedDialog Dataset Load**

# %%
from datasets import load_dataset

# Load 10k English MedDialog dataset
dataset = load_dataset("BinKhoaLe1812/MedDialog-EN-10k")

print(dataset)
print(dataset["train"][0])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/119 [00:00<?, ?B/s]
# iCliniq.json:   0%|          | 0.00/19.5M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7321 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'answer_icliniq', 'answer_chatgpt', 'answer_chatdoctor'],
#         num_rows: 7321
#     })
# })
# {'input': 'Hello doctor,I had mumps five months ago and after that, I started to have an infection in my left testes. It was swollen and now it has shrunk to almost half the size of the other one. As I am sexually active, I feel a pain in each of the vas deferens after sex. If I do not have sex for days, they become sensitive. I was treated with Ceftum 500 mg, the first time I had an infection. Now my question is, is there any chance that the infection is still in my body? And, do I need to get examined for it? For the time being, please suggest some precautionary antibiotics for my relief.', 'answer_icliniq': 'Hello, Welcome to Chat Doctor forum. I can understand your concern. You had mumps and this is a viral infection known to cause an inflammation of the testis in some cases. Take care. For more information consult a sexologist online ', 'answer_chatgpt': "It is possible that you still have an infection in your testes, especially if you have been experiencing pain and sensitivity in your vas deferens. It is recommended that you consult with a doctor or urologist for an examination and further testing to determine if there is an ongoing infection.\n\nAs an AI language model, I cannot prescribe medications or antibiotics. However, taking antibiotics without a doctor's prescription is not recommended. It is important to consult with a healthcare professional for proper diagnosis and treatment.", 'answer_chatdoctor': '1) There is no need to worry about reinfection as the infection caused by Mumps virus does not persist in the body and is completely cleared up by the immune system.2) The swelling at your scrotum is due to inflammation of epididymis or vas deferens which is a result of mumps infection.3) There is no need to take antibiotics for this problem. You can take anti-inflammatory medicines like Ibuprofen for symptomatic relief.4) Doing cool compresses over the scrotal area will help in reducing the inflammation and pain.'}

# %% [markdown]
# # **converting to audio**

# %%
from gtts import gTTS
import os, time, re

output_dir = "/content/drive/MyDrive/DASYSTEM2/synthetic_audio_gtts"
os.makedirs(output_dir, exist_ok=True)

for i, row in enumerate(dataset["train"]):
    try:
        # Clean and get text
        patient_text = row["input"].strip()
        doctor_text = row["answer_icliniq"].strip()

        # Skip if no text
        if not patient_text and not doctor_text:
            print(f"⚠️ Index {i} has no text. Skipping.")
            continue

        # Optional: add slow speech trick with punctuation
        def slowify(text):
            text = text.replace(",", ",,").replace(".", "..")
            return text

        if patient_text:
            tts = gTTS(slowify(patient_text), lang="en", slow=True)
            tts.save(os.path.join(output_dir, f"patient_{i}.mp3"))
            print(f"🎧 Saved patient_{i}.mp3")


        time.sleep(1)  # small delay

    except Exception as e:
        print(f"⚠️ Error at index {i}: {e}")
        time.sleep(5)
# Out:
# 🎧 Saved patient_0.mp3
# 🎧 Saved patient_1.mp3
# 🎧 Saved patient_2.mp3
# 🎧 Saved patient_3.mp3
# 🎧 Saved patient_4.mp3
# 🎧 Saved patient_5.mp3
# 🎧 Saved patient_6.mp3
# 🎧 Saved patient_7.mp3
# 🎧 Saved patient_8.mp3
# 🎧 Saved patient_9.mp3
# 🎧 Saved patient_10.mp3
# 🎧 Saved patient_11.mp3
# 🎧 Saved patient_12.mp3
# 🎧 Saved patient_13.mp3
# 🎧 Saved patient_14.mp3
# 🎧 Saved patient_15.mp3
# 🎧 Saved patient_16.mp3
# 🎧 Saved patient_17.mp3
# 🎧 Saved patient_18.mp3
# 🎧 Saved patient_19.mp3
# 🎧 Saved patient_20.mp3
# 🎧 Saved patient_21.mp3
# 🎧 Saved patient_22.mp3
# 🎧 Saved patient_23.mp3
# 🎧 Saved patient_24.mp3
# 🎧 Saved patient_25.mp3
# 🎧 Saved patient_26.mp3
# 🎧 Saved patient_27.mp3
# 🎧 Saved patient_28.mp3
# 🎧 Saved patient_29.mp3
# 🎧 Saved patient_30.mp3
# 🎧 Saved patient_31.mp3
# 🎧 Saved patient_32.mp3
# 🎧 Saved patient_33.mp3
# 🎧 Saved patient_34.mp3
# 🎧 Saved patient_35.mp3
# 🎧 Saved patient_36.mp3
# 🎧 Saved patient_37.mp3
# 🎧 Saved patient_38.mp3
# 🎧 Saved patient_39.mp3
# 🎧 Saved patient_40.mp3
# 🎧 Saved patient_41.mp3
# 🎧 Saved patient_42.mp3
# 🎧 Saved patient_43.mp3
# 🎧 Saved patient_44.mp3
# 🎧 Saved patient_45.mp3
# 🎧 Saved patient_46.mp3
# 🎧 Saved patient_47.mp3
# 🎧 Saved patient_48.mp3
# 🎧 Saved patient_49.mp3
# 🎧 Saved patient_50.mp3
# 🎧 Saved patient_51.mp3
# 🎧 Saved patient_52.mp3
# 🎧 Saved patient_53.mp3
# 🎧 Saved patient_54.mp3
# 🎧 Saved patient_55.mp3
# 🎧 Saved patient_56.mp3
# 🎧 Saved patient_57.mp3
# 🎧 Saved patient_58.mp3
# 🎧 Saved patient_59.mp3
# 🎧 Saved patient_60.mp3
# 🎧 Saved patient_61.mp3
# 🎧 Saved patient_62.mp3
# 🎧 Saved patient_63.mp3
# 🎧 Saved patient_64.mp3
# 🎧 Saved patient_65.mp3
# 🎧 Saved patient_66.mp3
# 🎧 Saved patient_67.mp3
# 🎧 Saved patient_68.mp3
# 🎧 Saved patient_69.mp3
# 🎧 Saved patient_70.mp3
# 🎧 Saved patient_71.mp3
# 🎧 Saved patient_72.mp3
# 🎧 Saved patient_73.mp3
# 🎧 Saved patient_74.mp3
# 🎧 Saved patient_75.mp3
# 🎧 Saved patient_76.mp3
# 🎧 Saved patient_77.mp3
# 🎧 Saved patient_78.mp3
# 🎧 Saved patient_79.mp3
# 🎧 Saved patient_80.mp3
# 🎧 Saved patient_81.mp3
# 🎧 Saved patient_82.mp3
# 🎧 Saved patient_83.mp3
# 🎧 Saved patient_84.mp3
# 🎧 Saved patient_85.mp3
# 🎧 Saved patient_86.mp3
# 🎧 Saved patient_87.mp3
# 🎧 Saved patient_88.mp3
# 🎧 Saved patient_89.mp3
# 🎧 Saved patient_90.mp3
# 🎧 Saved patient_91.mp3
# 🎧 Saved patient_92.mp3
# 🎧 Saved patient_93.mp3
# 🎧 Saved patient_94.mp3
# 🎧 Saved patient_95.mp3
# 🎧 Saved patient_96.mp3
# 🎧 Saved patient_97.mp3
# 🎧 Saved patient_98.mp3
# 🎧 Saved patient_99.mp3
# 🎧 Saved patient_100.mp3
# 🎧 Saved patient_101.mp3
# 🎧 Saved patient_102.mp3
# 🎧 Saved patient_103.mp3
# 🎧 Saved patient_104.mp3
# 🎧 Saved patient_105.mp3
# 🎧 Saved patient_106.mp3
# 🎧 Saved patient_107.mp3
# 🎧 Saved patient_108.mp3
# 🎧 Saved patient_109.mp3
# 🎧 Saved patient_110.mp3
# 🎧 Saved patient_111.mp3
# 🎧 Saved patient_112.mp3
# 🎧 Saved patient_113.mp3
# 🎧 Saved patient_114.mp3
# 🎧 Saved patient_115.mp3
# 🎧 Saved patient_116.mp3
# 🎧 Saved patient_117.mp3
# 🎧 Saved patient_118.mp3
# 🎧 Saved patient_119.mp3
# 🎧 Saved patient_120.mp3
# 🎧 Saved patient_121.mp3
# 🎧 Saved patient_122.mp3
# 🎧 Saved patient_123.mp3
# 🎧 Saved patient_124.mp3
# 🎧 Saved patient_125.mp3
# 🎧 Saved patient_126.mp3
# 🎧 Saved patient_127.mp3
# 🎧 Saved patient_128.mp3
# 🎧 Saved patient_129.mp3
# 🎧 Saved patient_130.mp3
# 🎧 Saved patient_131.mp3
# 🎧 Saved patient_132.mp3
# 🎧 Saved patient_133.mp3
# 🎧 Saved patient_134.mp3
# 🎧 Saved patient_135.mp3
# 🎧 Saved patient_136.mp3
# 🎧 Saved patient_137.mp3
# 🎧 Saved patient_138.mp3
# 🎧 Saved patient_139.mp3
# 🎧 Saved patient_140.mp3
# 🎧 Saved patient_141.mp3
# 🎧 Saved patient_142.mp3
# 🎧 Saved patient_143.mp3
# 🎧 Saved patient_144.mp3
# 🎧 Saved patient_145.mp3
# 🎧 Saved patient_146.mp3
# 🎧 Saved patient_147.mp3
# 🎧 Saved patient_148.mp3
# 🎧 Saved patient_149.mp3
# 🎧 Saved patient_150.mp3
# 🎧 Saved patient_151.mp3
# 🎧 Saved patient_152.mp3
# 🎧 Saved patient_153.mp3
# 🎧 Saved patient_154.mp3
# 🎧 Saved patient_155.mp3
# 🎧 Saved patient_156.mp3
# 🎧 Saved patient_157.mp3
# 🎧 Saved patient_158.mp3
# 🎧 Saved patient_159.mp3
# 🎧 Saved patient_160.mp3
# 🎧 Saved patient_161.mp3
# 🎧 Saved patient_162.mp3
# 🎧 Saved patient_163.mp3
# 🎧 Saved patient_164.mp3
# 🎧 Saved patient_165.mp3
# 🎧 Saved patient_166.mp3
# 🎧 Saved patient_167.mp3
# 🎧 Saved patient_168.mp3
# ⚠️ Error at index 169: 429 (Too Many Requests) from TTS API. Probable cause: Unknown
# ⚠️ Error at index 170: 429 (Too Many Requests) from TTS API. Probable cause: Unknown
# ⚠️ Error at index 171: 429 (Too Many Requests) from TTS API. Probable cause: Unknown
# ⚠️ Error at index 172: 429 (Too Many Requests) from TTS API. Probable cause: Unknown
# ⚠️ Error at index 173: 429 (Too Many Requests) from TTS API. Probable cause: Unknown
# ⚠️ Error at index 174: 429 (Too Many Requests) from TTS API. Probable cause: Unknown
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/gtts/tts.py in stream(self)
#     278
# --> 279                 r.raise_for_status()
#     280             except requests.exceptions.HTTPError as e:  # pragma: no cover
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://translate.google.com/_/TranslateWebserverUi/data/batchexecute&q=EgSIbhBdGLT93cgGIjAj41Xcj3eH9mp-1rHsMK6xjlLvXcRQqySF8y1_XN5GrsKd80Ojr-Td0sSTtxZfmqQyAnJSWgFD
#
# During handling of the above exception, another exception occurred:
#
# gTTSError                                 Traceback (most recent call last)
# /tmp/ipython-input-3122304287.py in <cell line: 0>()
#      24             tts = gTTS(slowify(patient_text), lang="en", slow=True)
# ---> 25             tts.save(os.path.join(output_dir, f"patient_{i}.mp3"))
#      26             print(f"🎧 Saved patient_{i}.mp3")
#
# /usr/local/lib/python3.12/dist-packages/gtts/tts.py in save(self, savefile)
#     334         with open(str(savefile), "wb") as f:
# --> 335             self.write_to_fp(f)
#     336             f.flush()
#
# /usr/local/lib/python3.12/dist-packages/gtts/tts.py in write_to_fp(self, fp)
#     315         try:
# --> 316             for idx, decoded in enumerate(self.stream()):
#     317                 fp.write(decoded)
#
# /usr/local/lib/python3.12/dist-packages/gtts/tts.py in stream(self)
#     282                 log.debug(str(e))
# --> 283                 raise gTTSError(tts=self, response=r)
#     284             except requests.exceptions.RequestException as e:  # pragma: no cover
#
# gTTSError: 429 (Too Many Requests) from TTS API. Probable cause: Unknown
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3122304287.py in <cell line: 0>()
#      31     except Exception as e:
#      32         print(f"⚠️ Error at index {i}: {e}")
# ---> 33         time.sleep(5)
#
# KeyboardInterrupt:

# %% [markdown]
# **Audio Preprocessing**

# %%
from pydub import AudioSegment
import os

# Directory with synthetic audio
input_dir = "/content/drive/MyDrive/DASYSTEM2/synthetic_audio_gtts"
processed_dir = "/content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed"
os.makedirs(processed_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.endswith(".mp3"):
        audio = AudioSegment.from_file(os.path.join(input_dir, file))
        audio = audio.set_frame_rate(16000).set_channels(1)
        output_file = os.path.join(processed_dir, file.replace(".mp3", ".wav"))
        audio.export(output_file, format="wav")
        print(f"Processed {file} -> {output_file}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Processed patient_0.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_0.wav
# Processed patient_1.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_1.wav
# Processed patient_2.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_2.wav
# Processed patient_3.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_3.wav
# Processed patient_4.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_4.wav
# Processed patient_5.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_5.wav
# Processed patient_6.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_6.wav
# Processed patient_7.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_7.wav
# Processed patient_8.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_8.wav
# Processed patient_9.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_9.wav
# Processed patient_10.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_10.wav
# Processed patient_11.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_11.wav
# Processed patient_12.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_12.wav
# Processed patient_13.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_13.wav
# Processed patient_14.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_14.wav
# Processed patient_15.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_15.wav
# Processed patient_16.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_16.wav
# Processed patient_17.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_17.wav
# Processed patient_18.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_18.wav
# Processed patient_19.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_19.wav
# Processed patient_20.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_20.wav
# Processed patient_21.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_21.wav
# Processed patient_22.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_22.wav
# Processed patient_23.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_23.wav
# Processed patient_24.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_24.wav
# Processed patient_25.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_25.wav
# Processed patient_26.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_26.wav
# Processed patient_27.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_27.wav
# Processed patient_28.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_28.wav
# Processed patient_29.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_29.wav
# Processed patient_30.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_30.wav
# Processed patient_31.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_31.wav
# Processed patient_32.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_32.wav
# Processed patient_33.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_33.wav
# Processed patient_34.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_34.wav
# Processed patient_35.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_35.wav
# Processed patient_36.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_36.wav
# Processed patient_37.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_37.wav
# Processed patient_38.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_38.wav
# Processed patient_39.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_39.wav
# Processed patient_40.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_40.wav
# Processed patient_41.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_41.wav
# Processed patient_42.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_42.wav
# Processed patient_43.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_43.wav
# Processed patient_44.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_44.wav
# Processed patient_45.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_45.wav
# Processed patient_46.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_46.wav
# Processed patient_47.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_47.wav
# Processed patient_48.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_48.wav
# Processed patient_49.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_49.wav
# Processed patient_50.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_50.wav
# Processed patient_51.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_51.wav
# Processed patient_52.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_52.wav
# Processed patient_53.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_53.wav
# Processed patient_54.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_54.wav
# Processed patient_55.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_55.wav
# Processed patient_56.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_56.wav
# Processed patient_57.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_57.wav
# Processed patient_58.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_58.wav
# Processed patient_59.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_59.wav
# Processed patient_60.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_60.wav
# Processed patient_61.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_61.wav
# Processed patient_62.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_62.wav
# Processed patient_63.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_63.wav
# Processed patient_64.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_64.wav
# Processed patient_65.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_65.wav
# Processed patient_66.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_66.wav
# Processed patient_67.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_67.wav
# Processed patient_68.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_68.wav
# Processed patient_69.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_69.wav
# Processed patient_70.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_70.wav
# Processed patient_71.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_71.wav
# Processed patient_72.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_72.wav
# Processed patient_73.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_73.wav
# Processed patient_74.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_74.wav
# Processed patient_75.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_75.wav
# Processed patient_76.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_76.wav
# Processed patient_77.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_77.wav
# Processed patient_78.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_78.wav
# Processed patient_79.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_79.wav
# Processed patient_80.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_80.wav
# Processed patient_81.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_81.wav
# Processed patient_82.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_82.wav
# Processed patient_83.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_83.wav
# Processed patient_84.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_84.wav
# Processed patient_85.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_85.wav
# Processed patient_86.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_86.wav
# Processed patient_87.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_87.wav
# Processed patient_88.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_88.wav
# Processed patient_89.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_89.wav
# Processed patient_90.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_90.wav
# Processed patient_91.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_91.wav
# Processed patient_92.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_92.wav
# Processed patient_93.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_93.wav
# Processed patient_94.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_94.wav
# Processed patient_95.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_95.wav
# Processed patient_96.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_96.wav
# Processed patient_97.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_97.wav
# Processed patient_98.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_98.wav
# Processed patient_99.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_99.wav
# Processed patient_100.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_100.wav
# Processed patient_101.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_101.wav
# Processed patient_102.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_102.wav
# Processed patient_103.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_103.wav
# Processed patient_104.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_104.wav
# Processed patient_105.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_105.wav
# Processed patient_106.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_106.wav
# Processed patient_107.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_107.wav
# Processed patient_108.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_108.wav
# Processed patient_109.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_109.wav
# Processed patient_110.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_110.wav
# Processed patient_111.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_111.wav
# Processed patient_112.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_112.wav
# Processed patient_113.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_113.wav
# Processed patient_114.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_114.wav
# Processed patient_115.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_115.wav
# Processed patient_116.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_116.wav
# Processed patient_117.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_117.wav
# Processed patient_118.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_118.wav
# Processed patient_119.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_119.wav
# Processed patient_120.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_120.wav
# Processed patient_121.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_121.wav
# Processed patient_122.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_122.wav
# Processed patient_123.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_123.wav
# Processed patient_124.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_124.wav
# Processed patient_125.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_125.wav
# Processed patient_126.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_126.wav
# Processed patient_127.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_127.wav
# Processed patient_128.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_128.wav
# Processed patient_129.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_129.wav
# Processed patient_130.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_130.wav
# Processed patient_131.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_131.wav
# Processed patient_132.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_132.wav
# Processed patient_133.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_133.wav
# Processed patient_134.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_134.wav
# Processed patient_135.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_135.wav
# Processed patient_136.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_136.wav
# Processed patient_137.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_137.wav
# Processed patient_138.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_138.wav
# Processed patient_139.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_139.wav
# Processed patient_140.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_140.wav
# Processed patient_141.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_141.wav
# Processed patient_142.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_142.wav
# Processed patient_143.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_143.wav
# Processed patient_144.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_144.wav
# Processed patient_145.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_145.wav
# Processed patient_146.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_146.wav
# Processed patient_147.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_147.wav
# Processed patient_148.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_148.wav
# Processed patient_149.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_149.wav
# Processed patient_150.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_150.wav
# Processed patient_151.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_151.wav
# Processed patient_152.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_152.wav
# Processed patient_153.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_153.wav
# Processed patient_154.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_154.wav
# Processed patient_155.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_155.wav
# Processed patient_156.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_156.wav
# Processed patient_157.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_157.wav
# Processed patient_158.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_158.wav
# Processed patient_159.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_159.wav
# Processed patient_160.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_160.wav
# Processed patient_161.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_161.wav
# Processed patient_162.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_162.wav
# Processed patient_163.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_163.wav
# Processed patient_164.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_164.wav
# Processed patient_165.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_165.wav
# Processed patient_166.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_166.wav
# Processed patient_167.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_167.wav
# Processed patient_168.mp3 -> /content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed/patient_168.wav

# %% [markdown]
# # **Transcripted**

# %%
import os
import whisper
model = whisper.load_model("large")  # or "large"


input_dir = "/content/drive/MyDrive/DASYSTEM2/synthetic_audio_processed"
transcripts_dir = "/content/drive/MyDrive/DASYSTEM2/transcript large"
os.makedirs(transcripts_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.endswith(".wav"):
        result = model.transcribe(os.path.join(input_dir, file))
        text = result['text']
        # Save transcript
        with open(os.path.join(transcripts_dir, file.replace(".wav", ".txt")), "w") as f:
            f.write(text)
        print(f"Transcribed {file} -> {text[:50]}...")
# Out:
# 100%|█████████████████████████████████████| 2.88G/2.88G [00:31<00:00, 98.9MiB/s]
# Transcribed patient_0.wav ->  Hello, Doctor. I had mumps five months ago and af...
# Transcribed patient_1.wav ->  Hello doctor, I am trying to conceive but my husb...
# Transcribed patient_2.wav ->  Hello, Doctor. I am currently on the Yaz contrace...
# Transcribed patient_3.wav ->  Hello doctor, my son aged 13 years has got his le...
# Transcribed patient_4.wav ->  Hello doctor, I just got one side of my wisdom te...
# Transcribed patient_5.wav ->  Hello doctor, I had deep unprotected sex for 3 mi...
# Transcribed patient_6.wav ->  Hello doctor, I need advice after my second CT ch...
# Transcribed patient_7.wav ->  Hi, Doctor. I had sex for the first time. After t...
# Transcribed patient_8.wav ->  Hello doctor, my friend aged 30 had two drops of ...
# Transcribed patient_9.wav ->  Hello doctor, some mornings during the week I get...
# Transcribed patient_10.wav ->  Hi Doctor, my last USG report showed intrauterine...
# Transcribed patient_11.wav ->  I'm 40 and I've had glandular fever, shingles, in...
# Transcribed patient_12.wav ->  Hello doctor, I am a 50 year old female who has h...
# Transcribed patient_13.wav ->  Hello doctor, I have had a fishy odor down there ...
# Transcribed patient_14.wav ->  Hello, Doctor. My body is getting severe itching ...
# Transcribed patient_15.wav ->  Hi, Doctor. I am a 25-year-old male. I do not hav...
# Transcribed patient_16.wav ->  Hello, Doctor. My mother is 75 years old. She had...
# Transcribed patient_17.wav ->  Hi Doctor, I am suffering from a mild cold and se...
# Transcribed patient_18.wav ->  Hi doctor, my wife missed her periods and we doub...
# Transcribed patient_19.wav ->  Hi Doctor, I have a question for my mother. My mo...
# Transcribed patient_20.wav ->  Hello doctor. A few months before, I developed a ...
# Transcribed patient_21.wav ->  Hello doctor, I would like to ask what is the lik...
# Transcribed patient_22.wav ->  Hello doctor, my son has developed anxiety sympto...
# Transcribed patient_23.wav ->  Hello doctor, I think a spider went up to my righ...
# Transcribed patient_24.wav ->  Hello doctor, my symptoms are extreme nausea, hea...
# Transcribed patient_25.wav ->  Hello doctor, I am seriously facing acne pimples ...
# Transcribed patient_26.wav ->  Hi doctor, my mother has a tumor-like thing in he...
# Transcribed patient_27.wav ->  Hi doctor, I am 18 years old. My problem is the t...
# Transcribed patient_28.wav ->  Hello, Doctor. My four-year-old son has some kind...
# Transcribed patient_29.wav ->  Hello doctor, I sustained an injury recently and ...
# Transcribed patient_30.wav ->  Hello doctor, my fiancé had a bleeding on the 25t...
# Transcribed patient_31.wav ->  Hello doctor, I recently have noticed a slight bl...
# Transcribed patient_32.wav ->  Hello, Doctor. I am a 23-year-old female. I am 70...
# Transcribed patient_33.wav ->  Hi Doctor, my wisdom tooth present in the lower l...
# Transcribed patient_34.wav ->  Hi, Doctor. I am a 20-year-old female, height 166...
# Transcribed patient_35.wav ->  Hi doctor, I have been treated with for a yeast i...
# Transcribed patient_36.wav ->  Hello doctor, my father recently had a heart atta...
# Transcribed patient_37.wav ->  Hello doctor, I have got an ear itching five days...
# Transcribed patient_38.wav ->  Hello, doctor. So, I have hives, also known as ch...
# Transcribed patient_39.wav ->  Hello Doctor, my friend underwent a USG and she w...
# Transcribed patient_40.wav ->  Hello doctor, I have hydroseal for so many years,...
# Transcribed patient_41.wav ->  Hello doctor, I have protected sex with stranger ...
# Transcribed patient_42.wav ->  Hello doctor, I had a back-to-back unprotected se...
# Transcribed patient_43.wav ->  Hello doctor, I was having spotting most of the m...
# Transcribed patient_44.wav ->  Hi doctor, my son is 6 years old. He has nasal bl...
# Transcribed patient_45.wav ->  Hello doctor, my vision was crystal clear this mo...
# Transcribed patient_46.wav ->  Hello, Doctor. Last night, I fell from my bike on...
# Transcribed patient_47.wav ->  Hi Doctor, my lab tests are as follows. 7 months ...
# Transcribed patient_48.wav ->  Hi Doctor, I have noticed that my first molar is ...
# Transcribed patient_49.wav ->  Hello Doctor, we have a 9 month old baby girl. Sh...
# Transcribed patient_50.wav ->  Hello doctor, I have red raised rashes in my legs...
# Transcribed patient_51.wav ->  Hello, doctor. I have been going to a dentist abo...
# Transcribed patient_52.wav ->  Hi, Doctor. I am 19 years old. I have pain in the...
# Transcribed patient_53.wav ->  Hi doctor, I just had an EGD with biopsy. Polypec...
# Transcribed patient_54.wav ->  Hello, Doctor. I am 29 years old, male. I am 173 ...
# Transcribed patient_55.wav ->  Hello doctor, is there a difference in alcoholic ...
# Transcribed patient_56.wav ->  Hello doctor, I have been diagnosed with mild her...
# Transcribed patient_57.wav ->  Hi doctor, my height is 5'4 and my weight is 61 k...
# Transcribed patient_58.wav ->  Hi Doctor, I am suffering from an infection on my...
# Transcribed patient_59.wav ->  Hello Doctor, I wanted to know if you could answe...
# Transcribed patient_60.wav ->  Hello doctor, can you please help me understand m...
# Transcribed patient_61.wav ->  Hi Doctor. I am a known diabetic for the past 15 ...
# Transcribed patient_62.wav ->  Hi Doctor, when I have the fever, can I take seto...
# Transcribed patient_63.wav ->  Hello doctor, I have small white and yellow lesio...
# Transcribed patient_64.wav ->  Hello doctor, three days ago. I had my atlas adju...
# Transcribed patient_65.wav ->  Hello, doctor. I am feeling really down. I have h...
# Transcribed patient_66.wav ->  Hi doctor, I have blood dots present under my ski...
# Transcribed patient_67.wav ->  Hello doctor, I had a silent missed abortion last...
# Transcribed patient_68.wav ->  Hi doctor, it is regarding my son. He is 14 month...
# Transcribed patient_69.wav ->  Hello doctor, I was suffering from an infection i...
# Transcribed patient_70.wav ->  Hello, Doctor. Around a year ago, some red pimple...
# Transcribed patient_71.wav ->  Hi doctor, I asked a question to you this morning...
# Transcribed patient_72.wav ->  Hi Doctor, I am coming here for what I think may ...
# Transcribed patient_73.wav ->  Hello, Doctor. My partner had a miscarriage unkno...
# Transcribed patient_74.wav ->  Hello, Doctor. I was diagnosed with dysphonia abo...
# Transcribed patient_75.wav ->  Hello doctor. I had a secondary burn on my calf. ...
# Transcribed patient_76.wav ->  Hello doctor. Attached is a treadmill stress test...
# Transcribed patient_77.wav ->  Hello Doctor, if TSH range is 18.64, does it mean...
# Transcribed patient_78.wav ->  Hi doctor, I have one white lump around the tonsi...
# Transcribed patient_79.wav ->  Hello doctor, I have a best friend who suffers fr...
# Transcribed patient_80.wav ->  Hello doctor, I had elevated alt levels between 5...
# Transcribed patient_81.wav ->  Hi doctor, I have a small pimple on the penis and...
# Transcribed patient_82.wav ->  Hello Doctor, after unsafe exposure, I got 49 day...
# Transcribed patient_83.wav ->  Hello, doctor. I am 16 years old and I wear conta...
# Transcribed patient_84.wav ->  Hi Doctor, while working out today, I was doing a...
# Transcribed patient_85.wav ->  Hello, Doctor. I am 26 years old. I have seen my ...
# Transcribed patient_86.wav ->  Hello Doctor, I have an astigmatism of O, D, minu...
# Transcribed patient_87.wav ->  Hello Doctor, my upper front tooth with root cana...
# Transcribed patient_88.wav ->  Hello doctor. Two years before, I got tested my w...
# Transcribed patient_89.wav ->  Hello doctor, I feel pain after eating some food ...
# Transcribed patient_90.wav ->  Hello doctor, I had kissed a prostitute on lips a...
# Transcribed patient_91.wav ->  Hello doctor, I have spastic paraplegia. Everythi...
# Transcribed patient_92.wav ->  Hello, Doctor. I am a 17-year-old. I am 5'7", in ...
# Transcribed patient_93.wav ->  Hello doctor, I am having back pain near the spin...
# Transcribed patient_94.wav ->  Hello doctor, I have an odd thing happening in my...
# Transcribed patient_95.wav ->  Hello Doctor, Hemoglobin, 14.3, Platelets, 174,00...
# Transcribed patient_96.wav ->  Hi doctor, I have not grown to the expected heigh...
# Transcribed patient_97.wav ->  Hello Doctor, I am 6 days post-operative from a f...
# Transcribed patient_98.wav ->  Hello, Doctor. I am an 18-year-old, and I have ex...
# Transcribed patient_99.wav ->  Hi Doctor, 5 years ago my mother was diagnosed wi...
# Transcribed patient_100.wav ->  Hello doctor, I am currently having acne on my ch...
# Transcribed patient_101.wav ->  Hello Doctor, I have a query on heavy periods sin...
# Transcribed patient_102.wav ->  Hello Doctor, I have been given Hepatitis B blood...
# Transcribed patient_103.wav ->  Hello doctor, I have had a feeling like something...
# Transcribed patient_104.wav ->  Hello Doctor. How to use a product called Contrac...
# Transcribed patient_105.wav ->  Hello doctor, just a few minutes before I was try...
# Transcribed patient_106.wav ->  Hello, Doctor. I am 32 years old. My sickness sta...
# Transcribed patient_107.wav ->  Hi doctor, I have been suffering from pain on the...
# Transcribed patient_108.wav ->  Hi doctor, from the last three years, I have seve...
# Transcribed patient_109.wav ->  Hi Doctor, I am having a lot of clotting bigger t...
# Transcribed patient_110.wav ->  Hi Doctor, I am having issues while doing interco...
# Transcribed patient_111.wav ->  Hello, Doctor. I am a 40-year-old male. I am a ve...
# Transcribed patient_112.wav ->  Hello Doctor, I am writing on behalf of my mother...
# Transcribed patient_113.wav ->  Hi doctor, I recently had unprotected sex with a ...
# Transcribed patient_114.wav ->  Hello Doctor, my sister is having a craniotomy op...
# Transcribed patient_115.wav ->  Hi Doctor, my mother is suffering from a left fem...
# Transcribed patient_116.wav ->  Hi doctor, my fiance and I are not known HIV posi...
# Transcribed patient_117.wav ->  Hello Doctor, just two days ago I found out I was...
# Transcribed patient_118.wav ->  Hello doctor, I have a roll or lump of fat under ...
# Transcribed patient_119.wav ->  Hi Doctor, I am 26 years old. Female. I have high...
# Transcribed patient_120.wav ->  Hello doctor, my 21 months old daughter has scrat...
# Transcribed patient_121.wav ->  Hello doctor, I am not satisfied with dental bond...
# Transcribed patient_122.wav ->  Hello, doctor. I had sex with a condom, but it to...
# Transcribed patient_123.wav ->  Dear Doctor, My age is 29 years. I had a surgery ...
# Transcribed patient_124.wav ->  Hello doctor, my eye power is only minus 0.5, but...
# Transcribed patient_125.wav ->  Hello, Doctor. Is it safe to take Chimoral Forte ...
# Transcribed patient_126.wav ->  Hi doctor, I have lots of anxiety issues. I have ...
# Transcribed patient_127.wav ->  Hello doctor, I am having black spots on the tong...
# Transcribed patient_128.wav ->  Hello doctor, my daughter aged 7 years has a urin...
# Transcribed patient_129.wav ->  Hello doctor, I need to know about cardiac dysfun...
# Transcribed patient_130.wav ->  Hi doctor, I am a 29 year old. My doctor said tha...
# Transcribed patient_131.wav ->  Hello doctor, I have cavities in the front two te...
# Transcribed patient_132.wav ->  What are some common causes of one-sided SI joint...
# Transcribed patient_133.wav ->  Hello Doctor. Earlier this year approximately 5 m...
# Transcribed patient_134.wav ->  Hello doctor, I am undergoing the fifth cycle of ...
# Transcribed patient_135.wav ->  Hello doctor, my daughter is two years old. Now, ...
# Transcribed patient_136.wav ->  Hello Doctor, my 13-year-old daughter has been su...
# Transcribed patient_137.wav ->  Hi doctor, my front tooth got chipped away before...
# Transcribed patient_138.wav ->  Hi doctor, my son hit his mouth on the bathtub wh...
# Transcribed patient_139.wav ->  Hello Doctor, I suffered from terrible anxiety an...
# Transcribed patient_140.wav ->  Hello doctor, my teeth are black. It looks like i...
# Transcribed patient_141.wav ->  Hello Doctor, I experienced a rash after an aller...
# Transcribed patient_142.wav ->  Hi, I am a 65-year-old female. My sugar level bef...
# Transcribed patient_143.wav ->  Hello doctor, I have a fever for almost three day...
# Transcribed patient_144.wav ->  Hi doctor, I am 27 years old and I have an embarr...
# Transcribed patient_145.wav ->  Hello doctor, about a year ago, I started with ti...
# Transcribed patient_146.wav ->  Hello Doctor, my first baby is healthy and my blo...
# Transcribed patient_147.wav ->  Hello, Doctor. I am a 30-year-old male who is a c...
# Transcribed patient_148.wav ->  Hello doctor. I have depression for the last four...
# Transcribed patient_149.wav ->  Hello doctor, I am a mother of two 1.7 months and...
# Transcribed patient_150.wav ->  Hello doctor, we are a newly married couple and h...
# Transcribed patient_151.wav ->  Hi doctor, I am 26 years old female. I have an ab...
# Transcribed patient_152.wav ->  Hello, Doctor. I have fever of 38 to 38.5 over pa...
# Transcribed patient_153.wav ->  Hi doctor, my daughter had braces for four years ...
# Transcribed patient_154.wav ->  Hello, Doctor. I am a 21-year-old female. Yesterd...
# Transcribed patient_155.wav ->  Hi doctor, I am 27 years old and I have multiple ...
# Transcribed patient_156.wav ->  Hi doctor, I have red bumps, which are non-itchy ...
# Transcribed patient_157.wav ->  Hello doctor. On my left eye. On the corner. Near...
# Transcribed patient_158.wav ->  Hello Doctor, what is HMD? Hereditary Macular Deg...
# Transcribed patient_159.wav ->  Hello, Doctor. I am 35-year-old male. My weight i...
# Transcribed patient_160.wav ->  Hello Doctor, can you please go through the Maste...
# Transcribed patient_161.wav ->  Hello doctor, I have been diagnosed hyperthyroid....
# Transcribed patient_162.wav ->  Hello doctor, I had been taking Trazodone 400mg a...
# Transcribed patient_163.wav ->  Hello, Doctor. I am a 46-year-old male. A month a...
# Transcribed patient_164.wav ->  Hi doctor, I am having frequent urination and fee...
# Transcribed patient_165.wav ->  Hello doctor. Suddenly, my right eye got smaller ...
# Transcribed patient_166.wav ->  Hi, I am getting white hair from last three years...
# Transcribed patient_167.wav ->  Hi Doctor, my scar revision surgery is not healin...
# Transcribed patient_168.wav ->  Hello doctor, I had my tooth checked up last year...

# %% [markdown]
# # **Text Profiling / Risk Analysis using fine tuned biobert**

# %%
# !pip install transformers torch scikit-learn pandas tqdm

import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModel
from torch import nn, optim
import torch.nn.functional as F
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm
from google.colab import drive

# ---------- CONFIG ----------
MODEL_NAME = "dmis-lab/biobert-base-cased-v1.2"
USE_GPU = torch.cuda.is_available()
DEVICE = "cuda" if USE_GPU else "cpu"
BATCH_SIZE = 8
EPOCHS = 3
MAX_LEN = 512
LEARNING_RATE = 2e-5

# ---------- Load dataset from Drive ----------
data_path = "/content/drive/MyDrive/DASYSTEM2/risk.csv"
df = pd.read_csv(data_path)

# Encode labels to integers: Low=0, Medium=1, High=2
le = LabelEncoder()
df['label_id'] = le.fit_transform(df['label'])

# ---------- Dataset class ----------
class RiskDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        label = self.labels[idx]
        encoding = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=MAX_LEN,
            return_tensors='pt'
        )
        item = {key: val.squeeze(0) for key, val in encoding.items()}
        item['labels'] = torch.tensor(label, dtype=torch.long)
        return item

# ---------- Load tokenizer and base model ----------
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
base_model = AutoModel.from_pretrained(MODEL_NAME)

# ---------- Classification head ----------
class BioBERTClassifier(nn.Module):
    def __init__(self, base_model, num_labels=3):
        super(BioBERTClassifier, self).__init__()
        self.base = base_model
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Linear(base_model.config.hidden_size, num_labels)

    def forward(self, input_ids, attention_mask):
        outputs = self.base(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state[:, 0]  # CLS token
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)
        return logits

model = BioBERTClassifier(base_model).to(DEVICE)

# ---------- Dataloader ----------
dataset = RiskDataset(df['text'].tolist(), df['label_id'].tolist(), tokenizer)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# ---------- Optimizer ----------
optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE)

# ---------- Training loop ----------
for epoch in range(EPOCHS):
    model.train()
    loop = tqdm(dataloader, leave=True)
    total_loss = 0
    for batch in loop:
        input_ids = batch['input_ids'].to(DEVICE)
        attention_mask = batch['attention_mask'].to(DEVICE)
        labels = batch['labels'].to(DEVICE)

        optimizer.zero_grad()
        logits = model(input_ids, attention_mask)
        loss = F.cross_entropy(logits, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        loop.set_description(f"Epoch {epoch+1}")
        loop.set_postfix(loss=loss.item())

    print(f"Epoch {epoch+1} completed. Avg loss: {total_loss/len(dataloader):.4f}")

# ---------- Save model ----------
save_dir = "/content/drive/MyDrive/DASYSTEM2/biobert_risk_model"
model_file = save_dir + "/biobert_risk_classifier.pt"
tokenizer_dir = save_dir + "/tokenizer"
import os
os.makedirs(save_dir, exist_ok=True)

torch.save(model.state_dict(), model_file)
tokenizer.save_pretrained(tokenizer_dir)
print("Model fine-tuned and saved to Drive!")
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Mounted at /content/drive
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/14 [00:01<?, ?it/s]
# Epoch 1:   0%|          | 0/14 [00:01<?, ?it/s, loss=1.22]
# Epoch 1:   7%|▋         | 1/14 [00:01<00:25,  1.93s/it, loss=1.22]
# Epoch 1:   7%|▋         | 1/14 [00:02<00:25,  1.93s/it, loss=1.22]
# Epoch 1:   7%|▋         | 1/14 [00:02<00:25,  1.93s/it, loss=1.27]
# Epoch 1:  14%|█▍        | 2/14 [00:02<00:14,  1.20s/it, loss=1.27]
# Epoch 1:  14%|█▍        | 2/14 [00:03<00:14,  1.20s/it, loss=1.27]
# Epoch 1:  14%|█▍        | 2/14 [00:03<00:14,  1.20s/it, loss=1.03]
# Epoch 1:  21%|██▏       | 3/14 [00:03<00:10,  1.02it/s, loss=1.03]
# Epoch 1:  21%|██▏       | 3/14 [00:03<00:10,  1.02it/s, loss=1.03]
# Epoch 1:  21%|██▏       | 3/14 [00:03<00:10,  1.02it/s, loss=1.24]
# Epoch 1:  29%|██▊       | 4/14 [00:03<00:08,  1.17it/s, loss=1.24]
# Epoch 1:  29%|██▊       | 4/14 [00:04<00:08,  1.17it/s, loss=1.24]
# Epoch 1:  29%|██▊       | 4/14 [00:04<00:08,  1.17it/s, loss=1.22]
# Epoch 1:  36%|███▌      | 5/14 [00:04<00:07,  1.27it/s, loss=1.22]
# Epoch 1:  36%|███▌      | 5/14 [00:05<00:07,  1.27it/s, loss=1.22]
# Epoch 1:  36%|███▌      | 5/14 [00:05<00:07,  1.27it/s, loss=1.09]
# Epoch 1:  43%|████▎     | 6/14 [00:05<00:05,  1.34it/s, loss=1.09]
# Epoch 1:  43%|████▎     | 6/14 [00:05<00:05,  1.34it/s, loss=1.09]
# Epoch 1:  43%|████▎     | 6/14 [00:05<00:05,  1.34it/s, loss=1.03]
# Epoch 1:  50%|█████     | 7/14 [00:05<00:05,  1.39it/s, loss=1.03]
# Epoch 1:  50%|█████     | 7/14 [00:06<00:05,  1.39it/s, loss=1.03]
# Epoch 1:  50%|█████     | 7/14 [00:06<00:05,  1.39it/s, loss=0.897]
# Epoch 1:  57%|█████▋    | 8/14 [00:06<00:04,  1.41it/s, loss=0.897]
# Epoch 1:  57%|█████▋    | 8/14 [00:07<00:04,  1.41it/s, loss=0.897]
# Epoch 1:  57%|█████▋    | 8/14 [00:07<00:04,  1.41it/s, loss=1.28]
# Epoch 1:  64%|██████▍   | 9/14 [00:07<00:03,  1.41it/s, loss=1.28]
# Epoch 1:  64%|██████▍   | 9/14 [00:08<00:03,  1.41it/s, loss=1.28]
# Epoch 1:  64%|██████▍   | 9/14 [00:08<00:03,  1.41it/s, loss=0.827]
# Epoch 1:  71%|███████▏  | 10/14 [00:08<00:02,  1.39it/s, loss=0.827]
# Epoch 1:  71%|███████▏  | 10/14 [00:08<00:02,  1.39it/s, loss=0.827]
# Epoch 1:  71%|███████▏  | 10/14 [00:08<00:02,  1.39it/s, loss=0.808]
# Epoch 1:  79%|███████▊  | 11/14 [00:08<00:02,  1.36it/s, loss=0.808]
# Epoch 1:  79%|███████▊  | 11/14 [00:09<00:02,  1.36it/s, loss=0.808]
# Epoch 1:  79%|███████▊  | 11/14 [00:09<00:02,  1.36it/s, loss=1.22]
# Epoch 1:  86%|████████▌ | 12/14 [00:09<00:01,  1.36it/s, loss=1.22]
# Epoch 1:  86%|████████▌ | 12/14 [00:10<00:01,  1.36it/s, loss=1.22]
# Epoch 1:  86%|████████▌ | 12/14 [00:10<00:01,  1.36it/s, loss=1.04]
# Epoch 1:  93%|█████████▎| 13/14 [00:10<00:00,  1.36it/s, loss=1.04]
# Epoch 1:  93%|█████████▎| 13/14 [00:10<00:00,  1.36it/s, loss=1.04]
# Epoch 1:  93%|█████████▎| 13/14 [00:10<00:00,  1.36it/s, loss=1.31]
# Epoch 1: 100%|██████████| 14/14 [00:10<00:00,  1.30it/s, loss=1.31]
# Epoch 1 completed. Avg loss: 1.1061
# Epoch 2: 100%|██████████| 14/14 [00:08<00:00,  1.56it/s, loss=0.586]
# Epoch 2 completed. Avg loss: 0.8940
# Epoch 3: 100%|██████████| 14/14 [00:09<00:00,  1.55it/s, loss=0.417]
# Epoch 3 completed. Avg loss: 0.6460
# Model fine-tuned and saved to Drive!

# %%
import os
import json
import torch
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModel
from fuzzywuzzy import fuzz
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# ---------- CONFIG ----------
transcripts_dir = "/content/drive/MyDrive/DASYSTEM2/transcript large"
output_dir = "/content/drive/MyDrive/DASYSTEM2/profile_results_biobert_patient_large"
os.makedirs(output_dir, exist_ok=True)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
MAX_LEN = 512
patient_prefix = "patient_"

# ---------- Keyword rules ----------
keywords_high_risk = ["chest pain", "shortness of breath", "severe bleeding"]
keywords_medium_risk = ["dizziness", "headache", "fever"]
FUZZY_THRESHOLD = 85

# ---------- Load tokenizer ----------
tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/DASYSTEM2/biobert_risk_model/tokenizer")

# ---------- Define model class ----------
class BioBERTClassifier(torch.nn.Module):
    def __init__(self, base_model, num_labels=3):
        super(BioBERTClassifier, self).__init__()
        self.base = base_model
        self.dropout = torch.nn.Dropout(0.3)
        self.classifier = torch.nn.Linear(base_model.config.hidden_size, num_labels)

    def forward(self, input_ids, attention_mask):
        outputs = self.base(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state[:, 0]  # CLS token
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)
        return logits

# ---------- Load base model ----------
base_model = AutoModel.from_pretrained("dmis-lab/biobert-base-cased-v1.2")
model = BioBERTClassifier(base_model).to(DEVICE)

# ---------- Load fine-tuned weights ----------
model.load_state_dict(torch.load("/content/drive/MyDrive/DASYSTEM2/biobert_risk_model/biobert_risk_classifier.pt", map_location=DEVICE))
model.eval()

# ---------- Load LabelEncoder ----------
df_labels = pd.read_csv("/content/drive/MyDrive/DASYSTEM2/risk.csv")
le = LabelEncoder()
le.fit(df_labels['label'])

# ---------- Risk prediction ----------
def predict_risk(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding='max_length', max_length=MAX_LEN).to(DEVICE)
    with torch.no_grad():
        logits = model(input_ids=inputs['input_ids'], attention_mask=inputs['attention_mask'])
        pred_label = torch.argmax(F.softmax(logits, dim=-1), dim=-1).item()
    return le.inverse_transform([pred_label])[0]

# ---------- Hybrid risk detection ----------
def detect_risk(text):
    text_lower = text.lower()
    # High-risk keywords
    for kw in keywords_high_risk:
        if fuzz.partial_ratio(kw.lower(), text_lower) >= FUZZY_THRESHOLD:
            return "High"
    # Medium-risk keywords
    for kw in keywords_medium_risk:
        if fuzz.partial_ratio(kw.lower(), text_lower) >= FUZZY_THRESHOLD:
            return "Medium"
    # Otherwise, use BioBERT prediction
    return predict_risk(text)

# ---------- Process all patient transcripts ----------
for fname in os.listdir(transcripts_dir):
    if not fname.endswith(".txt") or not fname.startswith(patient_prefix):
        continue

    file_path = os.path.join(transcripts_dir, fname)
    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read().strip()

    risk = detect_risk(text)

    # Save result
    out_path = os.path.join(output_dir, fname.replace(".txt", ".json"))
    with open(out_path, "w", encoding="utf-8") as out_f:
        json.dump({
            "file": fname,
            "risk_level": risk,
            "text": text
        }, out_f, ensure_ascii=False, indent=2)

    print(f"{fname} -> {risk}")
# Out:
# /usr/local/lib/python3.12/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# patient_0.txt -> Medium
# patient_1.txt -> Low
# patient_2.txt -> Low
# patient_3.txt -> Low
# patient_4.txt -> Medium
# patient_5.txt -> Medium
# patient_6.txt -> High
# patient_7.txt -> Low
# patient_8.txt -> Low
# patient_9.txt -> Medium
# patient_10.txt -> Medium
# patient_11.txt -> Medium
# patient_12.txt -> Medium
# patient_13.txt -> Low
# patient_14.txt -> Low
# patient_15.txt -> High
# patient_16.txt -> Low
# patient_17.txt -> Medium
# patient_18.txt -> Low
# patient_19.txt -> Low
# patient_20.txt -> Medium
# patient_21.txt -> Low
# patient_22.txt -> Medium
# patient_23.txt -> Medium
# patient_24.txt -> Medium
# patient_25.txt -> Low
# patient_26.txt -> Medium
# patient_27.txt -> Medium
# patient_28.txt -> Medium
# patient_29.txt -> Low
# patient_30.txt -> Low
# patient_31.txt -> High
# patient_32.txt -> High
# patient_33.txt -> Medium
# patient_34.txt -> Low
# patient_35.txt -> Low
# patient_36.txt -> Low
# patient_37.txt -> Medium
# patient_38.txt -> Low
# patient_39.txt -> Low
# patient_40.txt -> Medium
# patient_41.txt -> Low
# patient_42.txt -> Low
# patient_43.txt -> Low
# patient_44.txt -> Medium
# patient_45.txt -> Low
# patient_46.txt -> High
# patient_47.txt -> Medium
# patient_48.txt -> Low
# patient_49.txt -> Low
# patient_50.txt -> Low
# patient_51.txt -> Medium
# patient_52.txt -> High
# patient_53.txt -> Low
# patient_54.txt -> Low
# patient_55.txt -> Medium
# patient_56.txt -> Medium
# patient_57.txt -> Low
# patient_58.txt -> Low
# patient_59.txt -> Low
# patient_60.txt -> Low
# patient_61.txt -> Medium
# patient_62.txt -> Medium
# patient_63.txt -> Low
# patient_64.txt -> Medium
# patient_65.txt -> High
# patient_66.txt -> Medium
# patient_67.txt -> Low
# patient_68.txt -> Low
# patient_69.txt -> Low
# patient_70.txt -> Low
# patient_71.txt -> Low
# patient_72.txt -> Low
# patient_73.txt -> Low
# patient_74.txt -> Low
# patient_75.txt -> High
# patient_76.txt -> Low
# patient_77.txt -> Low
# patient_78.txt -> Medium
# patient_79.txt -> Medium
# patient_80.txt -> High
# patient_81.txt -> Low
# patient_82.txt -> High
# patient_83.txt -> Medium
# patient_84.txt -> Low
# patient_85.txt -> Low
# patient_86.txt -> Low
# patient_87.txt -> Medium
# patient_88.txt -> Medium
# patient_89.txt -> Medium
# patient_90.txt -> Low
# patient_91.txt -> Low
# patient_92.txt -> Low
# patient_93.txt -> Low
# patient_94.txt -> Low
# patient_95.txt -> Low
# patient_96.txt -> Low
# patient_97.txt -> Low
# patient_98.txt -> Low
# patient_99.txt -> Low
# patient_100.txt -> Low
# patient_101.txt -> Low
# patient_102.txt -> Medium
# patient_103.txt -> Medium
# patient_104.txt -> Low
# patient_105.txt -> Medium
# patient_106.txt -> Medium
# patient_107.txt -> Medium
# patient_108.txt -> Low
# patient_109.txt -> Low
# patient_110.txt -> Low
# patient_111.txt -> Low
# patient_112.txt -> Low
# patient_113.txt -> Low
# patient_114.txt -> High
# patient_115.txt -> Low
# patient_116.txt -> Low
# patient_117.txt -> Low
# patient_118.txt -> High
# patient_119.txt -> High
# patient_120.txt -> Medium
# patient_121.txt -> Medium
# patient_122.txt -> Medium
# patient_123.txt -> Low
# patient_124.txt -> Low
# patient_125.txt -> Low
# patient_126.txt -> High
# patient_127.txt -> Medium
# patient_128.txt -> Low
# patient_129.txt -> Medium
# patient_130.txt -> Low
# patient_131.txt -> High
# patient_132.txt -> Low
# patient_133.txt -> Low
# patient_134.txt -> Medium
# patient_135.txt -> Low
# patient_136.txt -> Medium
# patient_137.txt -> Low
# patient_138.txt -> Low
# patient_139.txt -> Medium
# patient_140.txt -> Low
# patient_141.txt -> Medium
# patient_142.txt -> High
# patient_143.txt -> High
# patient_144.txt -> Low
# patient_145.txt -> Medium
# patient_146.txt -> Low
# patient_147.txt -> High
# patient_148.txt -> Low
# patient_149.txt -> Medium
# patient_150.txt -> Low
# patient_151.txt -> Low
# patient_152.txt -> High
# patient_153.txt -> Low
# patient_154.txt -> High
# patient_155.txt -> High
# patient_156.txt -> Medium
# patient_157.txt -> Low
# patient_158.txt -> Low
# patient_159.txt -> High
# patient_160.txt -> Low
# patient_161.txt -> Low
# patient_162.txt -> Low
# patient_163.txt -> Medium
# patient_164.txt -> High
# patient_165.txt -> High
# patient_166.txt -> Medium
# patient_167.txt -> Medium
# patient_168.txt -> Low

# %% [markdown]
# # **Alert System via Mail**

# %%
import os
import json
import time
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# --- Gmail Configuration ---
GMAIL_USER = "xyz@gmail.com"
GMAIL_APP_PASSWORD = "abcdisn"  # App Password required

# --- Function to Send Alerts via Gmail SSL ---
def send_alert_smtplib(to_email, subject, message, retries=1):
    attempt = 0
    while attempt <= retries:
        try:
            # Create email message
            msg = MIMEMultipart()
            msg['From'] = GMAIL_USER
            msg['To'] = to_email
            msg['Subject'] = subject
            msg.attach(MIMEText(message, 'plain'))

            # Connect using SSL (port 465)
            server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
            server.login(GMAIL_USER, GMAIL_APP_PASSWORD)
            server.send_message(msg)
            server.quit()

            print(f"📧 Alert sent to {to_email} (Attempt {attempt+1})")
            return True
        except Exception as e:
            print(f"⚠️ Attempt {attempt+1} failed to send email to {to_email}: {e}")
            attempt += 1
            time.sleep(5)  # wait before retrying

    return False


# --- JSON Alert Loop ---
doctor_email = "xyz@gmail.com"
profile_dir = "/content/drive/MyDrive/DASYSTEM2/profile_results_biobert_patient_large"

for file in os.listdir(profile_dir):
    if file.endswith(".json"):
        file_path = os.path.join(profile_dir, file)
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        risk = data.get("risk_level", "Low")
        transcript = data.get("text", "")

        if risk in ["Medium", "High"]:
            subject = f"⚠️ {risk} Risk Alert from Patient Audio"
            message = f"Detected {risk} risk in patient audio.\n\nTranscript:\n{transcript}"

            success = send_alert_smtplib(doctor_email, subject, message)
            if success:
                print(f"✅ ALERT SENT for {file}: {risk}")
            else:
                print(f"❌ Failed to send alert for {file}: {risk}")

            time.sleep(5)  # small delay to avoid SMTP rate limits
        else:
            print(f"{file} → Low (No alert sent)")
# Out:
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_0.json: Medium
# patient_1.json → Low (No alert sent)
# patient_2.json → Low (No alert sent)
# patient_3.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_4.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_5.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_6.json: High
# patient_7.json → Low (No alert sent)
# patient_8.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_9.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_10.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_11.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_12.json: Medium
# patient_13.json → Low (No alert sent)
# patient_14.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_15.json: High
# patient_16.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_17.json: Medium
# patient_18.json → Low (No alert sent)
# patient_19.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_20.json: Medium
# patient_21.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_22.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_23.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_24.json: Medium
# patient_25.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_26.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_27.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_28.json: Medium
# patient_29.json → Low (No alert sent)
# patient_30.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_31.json: High
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_32.json: High
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_33.json: Medium
# patient_34.json → Low (No alert sent)
# patient_35.json → Low (No alert sent)
# patient_36.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_37.json: Medium
# patient_38.json → Low (No alert sent)
# patient_39.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_40.json: Medium
# patient_41.json → Low (No alert sent)
# patient_42.json → Low (No alert sent)
# patient_43.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_44.json: Medium
# patient_45.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_46.json: High
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_47.json: Medium
# patient_48.json → Low (No alert sent)
# patient_49.json → Low (No alert sent)
# patient_50.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_51.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_52.json: High
# patient_53.json → Low (No alert sent)
# patient_54.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_55.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_56.json: Medium
# patient_57.json → Low (No alert sent)
# patient_58.json → Low (No alert sent)
# patient_59.json → Low (No alert sent)
# patient_60.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_61.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_62.json: Medium
# patient_63.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_64.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_65.json: High
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_66.json: Medium
# patient_67.json → Low (No alert sent)
# patient_68.json → Low (No alert sent)
# patient_69.json → Low (No alert sent)
# patient_70.json → Low (No alert sent)
# patient_71.json → Low (No alert sent)
# patient_72.json → Low (No alert sent)
# patient_73.json → Low (No alert sent)
# patient_74.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_75.json: High
# patient_76.json → Low (No alert sent)
# patient_77.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_78.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_79.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_80.json: High
# patient_81.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_82.json: High
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_83.json: Medium
# patient_84.json → Low (No alert sent)
# patient_85.json → Low (No alert sent)
# patient_86.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_87.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_88.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_89.json: Medium
# patient_90.json → Low (No alert sent)
# patient_91.json → Low (No alert sent)
# patient_92.json → Low (No alert sent)
# patient_93.json → Low (No alert sent)
# patient_94.json → Low (No alert sent)
# patient_95.json → Low (No alert sent)
# patient_96.json → Low (No alert sent)
# patient_97.json → Low (No alert sent)
# patient_98.json → Low (No alert sent)
# patient_99.json → Low (No alert sent)
# patient_100.json → Low (No alert sent)
# patient_101.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_102.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_103.json: Medium
# patient_104.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_105.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_106.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_107.json: Medium
# patient_108.json → Low (No alert sent)
# patient_109.json → Low (No alert sent)
# patient_110.json → Low (No alert sent)
# patient_111.json → Low (No alert sent)
# patient_112.json → Low (No alert sent)
# patient_113.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_114.json: High
# patient_115.json → Low (No alert sent)
# patient_116.json → Low (No alert sent)
# patient_117.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_118.json: High
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_119.json: High
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_120.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_121.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_122.json: Medium
# patient_123.json → Low (No alert sent)
# patient_124.json → Low (No alert sent)
# patient_125.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_126.json: High
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_127.json: Medium
# patient_128.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_129.json: Medium
# patient_130.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_131.json: High
# patient_132.json → Low (No alert sent)
# patient_133.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_134.json: Medium
# patient_135.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_136.json: Medium
# patient_137.json → Low (No alert sent)
# patient_138.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_139.json: Medium
# patient_140.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_141.json: Medium
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_142.json: High
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_143.json: High
# patient_144.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_145.json: Medium
# patient_146.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_147.json: High
# patient_148.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_149.json: Medium
# patient_150.json → Low (No alert sent)
# patient_151.json → Low (No alert sent)
# 📧 Alert sent to kjfariha610@gmail.com (Attempt 1)
# ✅ ALERT SENT for patient_152.json: High
# patient_153.json → Low (No alert sent)
# ⚠️ Attempt 1 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 6a1803df08f44-882863138c0sm50952936d6.16 - gsmtp')
# ⚠️ Attempt 2 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 d75a77b69052e-4ede86f2accsm48213711cf.12 - gsmtp')
# ❌ Failed to send alert for patient_154.json: High
# ⚠️ Attempt 1 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 6a1803df08f44-88286313195sm51239366d6.13 - gsmtp')
# ⚠️ Attempt 2 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 af79cd13be357-8b2d6742903sm141195385a.12 - gsmtp')
# ❌ Failed to send alert for patient_155.json: High
# ⚠️ Attempt 1 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 6a1803df08f44-88286588be1sm50215056d6.47 - gsmtp')
# ⚠️ Attempt 2 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 d75a77b69052e-4ede86d6071sm47005231cf.10 - gsmtp')
# ❌ Failed to send alert for patient_156.json: Medium
# patient_157.json → Low (No alert sent)
# patient_158.json → Low (No alert sent)
# ⚠️ Attempt 1 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 d75a77b69052e-4ede87e6abesm46439021cf.23 - gsmtp')
# ⚠️ Attempt 2 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 6a1803df08f44-882862ce5e6sm51196636d6.10 - gsmtp')
# ❌ Failed to send alert for patient_159.json: High
# patient_160.json → Low (No alert sent)
# patient_161.json → Low (No alert sent)
# patient_162.json → Low (No alert sent)
# ⚠️ Attempt 1 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 6a1803df08f44-882862ce5e6sm51199076d6.10 - gsmtp')
# ⚠️ Attempt 2 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 af79cd13be357-8b2af042c9csm530796285a.46 - gsmtp')
# ❌ Failed to send alert for patient_163.json: Medium
# ⚠️ Attempt 1 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 af79cd13be357-8b2af062fd9sm534287585a.51 - gsmtp')
# ⚠️ Attempt 2 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 af79cd13be357-8b2dd688d07sm80008685a.32 - gsmtp')
# ❌ Failed to send alert for patient_164.json: High
# ⚠️ Attempt 1 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 af79cd13be357-8b2bd0bfc23sm441749285a.17 - gsmtp')
# ⚠️ Attempt 2 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 6a1803df08f44-882863a3034sm51016876d6.27 - gsmtp')
# ❌ Failed to send alert for patient_165.json: High
# ⚠️ Attempt 1 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 d75a77b69052e-4ede86f242csm45313571cf.14 - gsmtp')
# ⚠️ Attempt 2 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 d75a77b69052e-4ede86b376dsm47875111cf.7 - gsmtp')
# ❌ Failed to send alert for patient_166.json: Medium
# ⚠️ Attempt 1 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 6a1803df08f44-882865a2fb6sm50979626d6.50 - gsmtp')
# ⚠️ Attempt 2 failed to send email to kjfariha610@gmail.com: (550, b'5.4.5 Daily user sending limit exceeded. For more information on Gmail\n5.4.5 sending limits go to\n5.4.5  https://support.google.com/a/answer/166852 6a1803df08f44-8828655f8f2sm51499136d6.41 - gsmtp')
# ❌ Failed to send alert for patient_167.json: Medium
# patient_168.json → Low (No alert sent)

# %% [markdown]
# # **Evaluation**

# %%
from datasets import load_dataset
import os

# ---------- Config ----------
output_dir = "/content/drive/MyDrive/DASYSTEM2/patient_transcripts_168"
os.makedirs(output_dir, exist_ok=True)

patient_prefix = "patient_"
num_patients = 168  # limit to first 168

# ---------- Load dataset ----------
dataset = load_dataset("BinKhoaLe1812/MedDialog-EN-10k")
train_data = dataset["train"]

# ---------- Save first 168 patient utterances ----------
for idx in range(num_patients):
    sample = train_data[idx]

    if isinstance(sample, dict):
        patient_text = sample["input"].strip()
    else:
        patient_text = sample["input"].strip()

    filename = f"{patient_prefix}{idx}.txt"
    path = os.path.join(output_dir, filename)

    with open(path, "w", encoding="utf-8") as f:
        f.write(patient_text)

print(f"Saved {num_patients} patient transcripts to {output_dir}")
# Out:
# Saved 168 patient transcripts to /content/drive/MyDrive/DASYSTEM2/patient_transcripts_168

# %%
import os
import time
from jiwer import wer
from tqdm import tqdm

# --- Paths ---
transcripts_dir = "/content/drive/MyDrive/DASYSTEM2/transcript large"
profile_dir = "/content/drive/MyDrive/DASYSTEM2/profile_results_biobert_patient_large"
dataset_dir = "/content/drive/MyDrive/DASYSTEM2/synthetic_audio_gtts"

# --- Load Dataset ---
from datasets import load_dataset
dataset = load_dataset("BinKhoaLe1812/MedDialog-EN-10k")

# --- Risk Keywords ---
keywords_high_risk = ["chest pain", "shortness of breath", "severe bleeding"]
keywords_medium_risk = ["dizziness", "headache", "fever"]

# --- Storage ---
wer_scores = []
alert_log = []

# --- Evaluation Loop ---
start_time = time.time()
for i in tqdm(range(300), desc="Evaluating patient transcripts"):
    patient_file = os.path.join(transcripts_dir, f"patient_{i}.txt")

    # Skip missing transcripts
    if not os.path.exists(patient_file):
        continue

    # Load transcript
    with open(patient_file, "r") as f:
        patient_transcript = f.read().strip()

    # Original reference text
    patient_ref = dataset["train"][i]["input"].strip()

    # WER
    patient_wer = wer(patient_ref, patient_transcript)
    wer_scores.append(patient_wer)

    # --- Risk Detection ---
    text_lower = patient_transcript.lower()
    predicted_risk = "Low"
    for kw in keywords_high_risk:
        if kw in text_lower:
            predicted_risk = "High"
            break
    if predicted_risk == "Low":
        for kw in keywords_medium_risk:
            if kw in text_lower:
                predicted_risk = "Medium"
                break


    profile_file = os.path.join(profile_dir, f"patient_{i}.txt")
    if os.path.exists(profile_file):
        with open(profile_file, "r") as f:
            lines = f.readlines()
        true_risk = lines[0].split(":")[1].strip()
    else:
        true_risk = "Low"

    # --- Alerts ---
    send_alert = predicted_risk in ["High", "Medium"]
    alert_log.append({
        "file": patient_file,
        "predicted_risk": predicted_risk,
        "true_risk": true_risk,
        "alert_sent": send_alert
    })

end_time = time.time()
latency = (end_time - start_time) / len(alert_log) if alert_log else 0

# --- Transcription Accuracy ---
avg_patient_wer = sum(wer_scores) / len(wer_scores)

# --- Alert Reliability ---
high_alerts = [a for a in alert_log if a["predicted_risk"]=="High"]
high_alerts_sent = [a for a in high_alerts if a["alert_sent"]]
high_alert_reliability = len(high_alerts_sent) / len(high_alerts) * 100 if high_alerts else 0

medium_alerts = [a for a in alert_log if a["predicted_risk"]=="Medium"]
medium_false_positives = [a for a in medium_alerts if not a["alert_sent"]]
medium_false_positive_rate = len(medium_false_positives) / len(medium_alerts) * 100 if medium_alerts else 0

# --- Scalability ---
scalability = len(alert_log) / (end_time - start_time) if alert_log else 0


print("=== Transcription Accuracy ===")
print(f"Average Patient WER: {avg_patient_wer:.2%}")

print("\n=== Alert Reliability ===")
print(f"High-risk alerts delivered: {high_alert_reliability:.2f}%")
print(f"Medium-risk false positive rate: {medium_false_positive_rate:.2f}%")

print("\n=== Latency ===")
print(f"Average processing time per file: {latency:.2f}s")

print("\n=== Scalability ===")
print(f"Files processed per second: {scalability:.2f}")
# Out:
# Evaluating patient transcripts: 100%|██████████| 300/300 [00:00<00:00, 461.99it/s]
# === Transcription Accuracy ===
# Average Patient WER: 13.84%
#
# === Alert Reliability ===
# High-risk alerts delivered: 100.00%
# Medium-risk false positive rate: 0.00%
#
# === Latency ===
# Average processing time per file: 0.00s
#
# === Scalability ===
# Files processed per second: 258.15

# %%
import os
import json
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support


profile_dir = "/content/drive/MyDrive/DASYSTEM2/profile_results_biobert_patient_large"
ground_truth_csv = "/content/drive/MyDrive/DASYSTEM2/ground_truth_21.csv"

# ---------- Load ground truth ----------
df_gt = pd.read_csv(ground_truth_csv)  # columns: patient_id,risk_level
gt_dict = dict(zip(df_gt['patient_id'], df_gt['risk_level']))

# ---------- Load predicted risk from JSONs ----------
y_true = []
y_pred = []

for patient_id in df_gt['patient_id']:
    json_file = os.path.join(profile_dir, f"patient_{patient_id}.json")
    if os.path.exists(json_file):
        with open(json_file, "r", encoding="utf-8") as f:
            data = json.load(f)
        predicted_risk = data.get("risk_level", "Low")
    else:
        predicted_risk = "Low"  # fallback if file missing
    y_true.append(gt_dict[patient_id])
    y_pred.append(predicted_risk)

# ---------- Compute Profiling Accuracy ----------
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true, y_pred, labels=["High","Medium","Low"], average="weighted"
)

print("=== Profiling Accuracy (21 patients) ===")
print(f"Precision: {precision:.2%}")
print(f"Recall:    {recall:.2%}")
print(f"F1-score:  {f1:.2%}")
# Out:
# === Profiling Accuracy (21 patients) ===
# Precision: 18.37%
# Recall:    42.86%
# F1-score:  25.71%
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # **Database**

# %% [markdown]
# Connect to a new SQLite **database**

# %%
import sqlite3
import os
import json
import time

# Connect (or create) database
conn = sqlite3.connect('/content/drive/MyDrive/DASYSTEM2/doctor_alert.db')
cursor = conn.cursor()

# Create tables
cursor.execute("""
CREATE TABLE IF NOT EXISTS transcripts (
    patient_id TEXT PRIMARY KEY,
    transcript TEXT,
    timestamp TEXT
)
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS alerts (
    patient_id TEXT PRIMARY KEY,
    risk_level TEXT,
    alert_sent INTEGER,
    timestamp TEXT
)
""")

conn.commit()

# %% [markdown]
# **Insert transcripts**

# %%
transcripts_dir = "/content/drive/MyDrive/DASYSTEM2/transcript large"

for fname in os.listdir(transcripts_dir):
    if fname.endswith(".txt"):
        patient_id = fname.replace(".txt", "")
        file_path = os.path.join(transcripts_dir, fname)
        with open(file_path, "r", encoding="utf-8") as f:
            transcript = f.read().strip()
        timestamp = time.strftime("%Y-%m-%d %H:%M:%S")

        cursor.execute("""
        INSERT OR REPLACE INTO transcripts (patient_id, transcript, timestamp)
        VALUES (?, ?, ?)
        """, (patient_id, transcript, timestamp))

conn.commit()

# %% [markdown]
# **Insert risk profiling / alert info**

# %%
profile_dir = "/content/drive/MyDrive/DASYSTEM2/profile_results_biobert_patient_large"

for fname in os.listdir(profile_dir):
    if fname.endswith(".json"):
        patient_id = fname.replace(".json", "")
        file_path = os.path.join(profile_dir, fname)
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        risk_level = data.get("risk_level", "Low")
        alert_sent = 1 if risk_level in ["Medium","High"] else 0
        timestamp = time.strftime("%Y-%m-%d %H:%M:%S")

        cursor.execute("""
        INSERT OR REPLACE INTO alerts (patient_id, risk_level, alert_sent, timestamp)
        VALUES (?, ?, ?, ?)
        """, (patient_id, risk_level, alert_sent, timestamp))

conn.commit()
conn.close()

# %%
conn = sqlite3.connect('/content/drive/MyDrive/DASYSTEM2/doctor_alert.db')
cursor = conn.cursor()

cursor.execute("SELECT * FROM transcripts LIMIT 5")
print(cursor.fetchall())

cursor.execute("SELECT * FROM alerts WHERE risk_level='High'")
print(cursor.fetchall())

conn.close()
# Out:
# [('patient_0', 'Hello, Doctor. I had mumps five months ago and after that, I started to have an infection in my left tests. It was swollen and now it has shrunk to almost half the size of the other one. As I am sexually active, I feel a pain in each of the vas deferens after sex. If I do not have sex for days, they become sensitive. I was treated with ceftam 500 milligrams the first time I had an infection. Now my question is, is there any chance that the infection is still in my body? And do I need to get examined for it? For the time being, please suggest some precautionary antibiotics for my relief.', '2025-11-15 11:31:41'), ('patient_1', 'Hello doctor, I am trying to conceive but my husband and I did cocaine a week ago. How long should my husband and I wait to safely continue to try to get pregnant? How long until it is out of our system? How long does cocaine stay in sperm? Thanks in advance.', '2025-11-15 11:31:41'), ('patient_2', 'Hello, Doctor. I am currently on the Yaz contraceptive pill. I skipped my sugar pills for around 4 months and had a breakthrough period this month. I had my period last week, but I still have some residual brown discharge for about a week now. Additionally, I had sex a few days ago and bled during it. Nothing hurts or is sore. I just want to know how long I am going to have the brown discharge and if I should be worried or if I should do anything about it.', '2025-11-15 11:31:41'), ('patient_3', 'Hello doctor, my son aged 13 years has got his left eye minus 11 and right with minus 8. I am now very worried what good precautions should I take with him. Can you suggest me what should I do?', '2025-11-15 11:31:41'), ('patient_4', 'Hello doctor, I just got one side of my wisdom teeth removed both upper and lower six days ago. And I have another one scheduled after two days for the left side. The upper is 100% fine. Which they pulled. The lower they pulled the tooth without removing the root because it was too close to the nerve. I do have some stitching in this area currently on the lower cheek. Noticed a hard lump about one inch between my lower jawline and cheek area. Is this normal because of swelling or something else? Currently taking amoxicillin 500mg and ibuprofen 600mg. Please let me know what this hard lump is. Also generally on... On the lower side where this lump is. Remains sore.', '2025-11-15 11:31:41')]
# [('patient_6', 'High', 1, '2025-11-15 11:31:44'), ('patient_15', 'High', 1, '2025-11-15 11:31:44'), ('patient_31', 'High', 1, '2025-11-15 11:31:44'), ('patient_32', 'High', 1, '2025-11-15 11:31:44'), ('patient_46', 'High', 1, '2025-11-15 11:31:44'), ('patient_52', 'High', 1, '2025-11-15 11:31:44'), ('patient_65', 'High', 1, '2025-11-15 11:31:44'), ('patient_75', 'High', 1, '2025-11-15 11:31:44'), ('patient_80', 'High', 1, '2025-11-15 11:31:44'), ('patient_82', 'High', 1, '2025-11-15 11:31:44'), ('patient_114', 'High', 1, '2025-11-15 11:31:44'), ('patient_118', 'High', 1, '2025-11-15 11:31:44'), ('patient_119', 'High', 1, '2025-11-15 11:31:44'), ('patient_126', 'High', 1, '2025-11-15 11:31:44'), ('patient_131', 'High', 1, '2025-11-15 11:31:44'), ('patient_142', 'High', 1, '2025-11-15 11:31:45'), ('patient_143', 'High', 1, '2025-11-15 11:31:45'), ('patient_147', 'High', 1, '2025-11-15 11:31:45'), ('patient_152', 'High', 1, '2025-11-15 11:31:45'), ('patient_154', 'High', 1, '2025-11-15 11:31:45'), ('patient_155', 'High', 1, '2025-11-15 11:31:45'), ('patient_159', 'High', 1, '2025-11-15 11:31:45'), ('patient_164', 'High', 1, '2025-11-15 11:31:45'), ('patient_165', 'High', 1, '2025-11-15 11:31:45')]

# %%
import sqlite3
import pandas as pd


conn = sqlite3.connect('/content/drive/MyDrive/DASYSTEM2/doctor_alert.db')

# Query: join transcripts and alerts
query = """
SELECT t.patient_id, t.transcript, a.risk_level, a.alert_sent, a.timestamp AS alert_time
FROM transcripts t
LEFT JOIN alerts a ON t.patient_id = a.patient_id
ORDER BY t.patient_id
"""

df_report = pd.read_sql(query, conn)
conn.close()

# Show the first 10 rows
print(df_report.head(10))

#save as CSV for submission
df_report.to_csv("/content/drive/MyDrive/DASYSTEM2/patient_report.csv", index=False)
# Out:
#     patient_id                                         transcript risk_level  \
# 0    patient_0  Hello, Doctor. I had mumps five months ago and...     Medium
# 1    patient_1  Hello doctor, I am trying to conceive but my h...        Low
# 2   patient_10  Hi Doctor, my last USG report showed intrauter...     Medium
# 3  patient_100  Hello doctor, I am currently having acne on my...        Low
# 4  patient_101  Hello Doctor, I have a query on heavy periods ...        Low
# 5  patient_102  Hello Doctor, I have been given Hepatitis B bl...     Medium
# 6  patient_103  Hello doctor, I have had a feeling like someth...     Medium
# 7  patient_104  Hello Doctor. How to use a product called Cont...        Low
# 8  patient_105  Hello doctor, just a few minutes before I was ...     Medium
# 9  patient_106  Hello, Doctor. I am 32 years old. My sickness ...     Medium
#
#    alert_sent           alert_time
# 0           1  2025-11-15 11:16:19
# 1           0  2025-11-15 11:16:19
# 2           1  2025-11-15 11:16:21
# 3           0  2025-11-15 11:16:21
# 4           0  2025-11-15 11:16:21
# 5           1  2025-11-15 11:16:21
# 6           1  2025-11-15 11:16:21
# 7           0  2025-11-15 11:16:21
# 8           1  2025-11-15 11:16:21
# 9           1  2025-11-15 11:16:21
